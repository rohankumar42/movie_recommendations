# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# ISVT, +_avg, LMaFit  [1, 2, 3, 4, 8, 16, 32, 64, 128]

data = np.array([
[1.9272, 1.0178, 0.9645, 0.9409, 0.94259, 0.9411, 0.9369, 0.9753, 1.0564, 1.2485, 1.5447],
[2.0477, 1.0199, 0.9678, 0.9542, 0.95470, 0.9476, 0.9577, 1.0149, 1.1347, 1.3880, 1.7549],
[1.8621, 1.0209, 0.9810, 0.9803, 0.98398, 0.9653, 0.9991, 1.0874, 1.2811, 1.6289, 2.0591],
[1.9439, 1.0271, 0.9903, 0.9967, 1.01495, 1.0544, 1.1143, 1.3229, 1.6995, 2.1156, 2.4289],
[2.7881, 1.0485, 1.0407, 1.0776, 1.12055, 1.1818, 1.3690, 1.7533, 2.1802, 2.4589, 2.6544],
[2.8127, 1.1105, 1.1172, 1.2889, 1.41475, 1.4971, 1.8579, 2.2495, 2.4983, 2.6614, 2.7561], 
[2.8127, 1.6123, 1.7247, 2.1169, 2.29902, 2.3942, 2.5779, 2.6861, 2.7505, 2.7842, 2.7978]])

# %%
# LMaFit vs ISVT vs +Avg


x_axis = [0.2, 0.4, 0.6, 0.8, 0.9, 0.95, 0.99]
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']
plt.figure(figsize=(8,6))


plt.plot(x_axis, data[:,0], marker="o", markersize=5, color=colors[0], label='ISVT')
plt.plot(x_axis, data[:,1], marker="o", markersize=5, color=colors[1], label='+Avg')
plt.plot(x_axis, data[:,3], marker="o", markersize=5, color=colors[2], label='LMaFit (k=2)')

plt.legend()
plt.legend(loc="upper left")
plt.xlabel('$p$ (Proportion of data used to test)')
plt.ylabel('RMSE')

plt.show()

# %%
# LMaFit vs Rank

ranks = [1, 2, 3, 4, 8, 16, 32, 64, 128]
x_axis = [0.2, 0.4, 0.6, 0.8, 0.9, 0.95, 0.99]

colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']
plt.figure(figsize=(8,6))

for i in range(1,10):
    plt.plot(x_axis, data[:,i], marker="o", markersize=5, color=colors[i], label=f'LMaFit (k={ranks[i-1]})')


plt.legend()
plt.legend(loc="upper left")
plt.xlabel('$p$ (Proportion of data used to test)')
plt.ylabel('RMSE')

plt.show()

# %%
# [LMaFit, 0.0, 0.1, 0.2, 0.5, 1.0]

bias_data = np.array([[0.9352031864787459, 0.9414695958978176, 0.9631355044852205, 0.9585379491705063, 1.048174603775535, 1.3153592665123852], 
[0.9452658356250901, 0.9462425693235322, 0.9518757797107771, 0.9769953940526024, 1.0630475059939701, 1.3078598931078205],
[0.9795219922662959, 0.9659537601079395, 0.9708115162069308, 1.0856096597457732, 1.074263313469592, 1.3151324394650652],
[0.9966531492951798, 0.9950364314938424, 0.9901256233428161, 1.006885048056629, 1.104139370731793, 1.3346329083309763],
[1.0713656912765335, 1.0782501255892962, 1.0953056397391756, 1.0889077095879154, 1.1617352920906248, 1.3875485977475206],
[1.28548413980267, 1.2637833758412205, 1.2992767218725965, 1.302794163165827, 1.3271619898747933, 1.5103011202022631],
[2.1145343590387826, 2.116923868887747, 2.126947354897401, 2.12229269014108, 2.1385504389183763, 2.1886458615022]])

# %%
# Biased LMaFit

x_axis = [0.2, 0.4, 0.6, 0.8, 0.9, 0.95, 0.99]
biases = [0.0, 0.1, 0.2, 0.5, 1.0]
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']
plt.figure(figsize=(8,6))

for i in range(1,6):
    plt.plot(x_axis, bias_data[:,i], marker="o", markersize=5, color=colors[i], label=f'LMaFit (b={biases[i-1]})')

plt.legend()
plt.legend(loc="upper left")
plt.xlabel('$p$ (Proportion of data used to test)')
plt.ylabel('RMSE')

plt.show()
